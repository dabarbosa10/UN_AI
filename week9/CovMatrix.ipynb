# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X=np.random.random(10)
Y=np.random.random(10)
print(X)
print(Y)
# Out:
# [0.56208643 0.98531405 0.52752055 0.41154982 0.04481676 0.56728373
#  0.24057057 0.21270036 0.58557131 0.81797446]
# [0.23703554 0.5416689  0.46126279 0.45056795 0.19759405 0.3688205
#  0.66238069 0.95076656 0.0088896  0.03621954]

# %%
def cov(x,y):
    xmean=np.mean(x)
    ymean=np.mean(y)
    return np.dot((x-xmean),(y-ymean))/(len(x)-1)

# %%
cov(X,Y)
# Out:
# -0.025548903299574002

# %%
np.array([[cov(X,X),cov(X,Y)], [cov(Y,X),cov(Y,Y)]])
# Out:
# array([[ 0.07975112, -0.0255489 ],
#        [-0.0255489 ,  0.08351667]])

# %%
np.cov(X,Y)
# Out:
# array([[ 0.07975112, -0.0255489 ],
#        [-0.0255489 ,  0.08351667]])

# %%
mu=[0,0]
sigma=[[0.6, 0.2],[0.2, 0.2]]
n=1000
x=np.random.multivariate_normal(mu,sigma,n).T

# %%
A=np.cov(x)
m = np.array([[1,2,3],[6,5,4]])
ms = m - m.mean(1).reshape(2,1)
np.dot(ms, ms.T)/2
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
e, v = np.linalg.eig(A)

# %%
plt.scatter(x[0,:], x[1,:], alpha=0.2)
for e_, v_ in zip(e, v.T):
    plt.plot([0, 3*e_*v_[0]], [0, 3*e_*v_[1]], 'r-', lw=2)
plt.axis([-3,3,-3,3])
plt.title('Eigenvectors of covariance matrix scaled by eigenvalue.');
