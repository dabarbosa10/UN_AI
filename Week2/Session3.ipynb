# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t=np.linspace(0,96,8)
E=np.array([1,0.4,-0.6,-0.9,-0.1,0.8,0.8,-0.18])
plt.plot(t,E,'*k')
plt.grid()

# %%
t1=np.linspace(0,100,1000)
y=np.cos(t1/12)
plt.plot(t,E,'*k')
plt.plot(t1,y,'r-')
plt.grid()
