# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
soa=np.array([[0,0,4,1],[0,0,1,5],[0,0,3,2]])
X,Y,U,V=zip(*soa)
plt.figure()
plt.title("Vectores")
ax=plt.gca()
ax.quiver(X,Y,U,V,angles='xy',scale_units='xy',scale=1)
ax.set_xlim([-1,6])
ax.set_ylim([-1,6])
plt.draw()

# %% [markdown]
# Producto Hadamard, elemento a elemento. (Importante en estadística).

# %%
a=np.array([1,2,3])
b=np.array([7,8,9])
a*b
# Out:
# array([ 7, 16, 27])

# %% [markdown]
# Combination of arrays for example using images:

# %%
v=np.ones([2,3])
w=np.array([2,2,2])
z=np.vstack((v,w))
print(z)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [2. 2. 2.]]

# %%
#Tensor de tamaño 10x10 en RGB por ejemplo
I=np.random.randint(0,255,size=(3,10,10))

# %%
plt.imshow(I.T) #Why transposition? Because the last argument in numpy is the RGB value

# %%
## Real Image
from skimage import data
from skimage.color import rgb2gray

# %%
original=data.astronaut()
grayscale=rgb2gray(original)

# %%
fig, axes=plt.subplots(1,2,figsize=(8,4))
ax=axes.ravel()

ax[0].imshow(original)
ax[0].set_title=('Original')
ax[1].imshow(grayscale, cmap=plt.cm.gray)
ax[1].set_title("Grayscale")

fig.tight_layout()

# %%
original.shape
# Out:
# (512, 512, 3)
