# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
import pandas as pd

# %%
data=pd.read_csv("6class.csv")

# %%
data.head()
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
data
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %%
data.columns
# Out:
# Index(['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)',
#        'Absolute magnitude(Mv)', 'Star type', 'Star color', 'Spectral Class'],
#       dtype='object')

# %%
data.hist('Temperature (K)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc9d1785fd0>]],
#       dtype=object)

# %%
data.hist('Luminosity(L/Lo)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc9d1b01a90>]],
#       dtype=object)

# %%
sns.pairplot(data,diag_kind="hist")

# %%
sns.regplot(x=data['Temperature (K)'],y=data['Absolute magnitude(Mv)'])

# %%
sns.scatterplot(x=data['Temperature (K)'],y=data['Absolute magnitude(Mv)'],hue=data['Star type'])

# %%
sns.scatterplot(x=data['Temperature (K)'],y=data['Absolute magnitude(Mv)'],hue=data['Spectral Class'])

# %%
sns.set(font_scale = 2)
sns.pairplot(data,hue='Star type',aspect=1,height=8)
